# %%
import torch
import matplotlib.pyplot as plt
# %matplotlib inline
torch.set_printoptions(sci_mode=False,precision=4)
torch.manual_seed(123)
torch.random.manual_seed(123)
generator = torch.Generator().manual_seed(123)

# %%
with open('../data/numeric_data.txt', 'r', encoding = 'utf-8') as file:
    names = file.read()

# %%
context_size = 25
embd_dim = 20
logging = False

device = torch.device("cpu" if torch.backends.mps.is_available() else "cpu")
batch_size = 8 if device.type == "mps" else 8
print(device, "| batch_size (before clamp):", batch_size)
# Out:
# cpu | batch_size (before clamp): 8

# %%
data = ''.join(names)
data = '_' * context_size + data
unique_text = sorted(list(set(data)))
vocab_size = len(unique_text)

# print(''.join(unique_text))
# print(len(''.join(unique_text)))

stoi = {text: index for index, text in enumerate(unique_text)}
itos = {index: text for index, text in enumerate(unique_text)}

encoder = lambda char_array: [stoi[char] for char in ''.join(char_array)]
decoder = lambda num_array: [itos[num] for num in num_array]

# %%
print(stoi)
# Out:
# {'\n': 0, ' ': 1, ',': 2, '.': 3, '3': 4, ':': 5, '?': 6, 'A': 7, 'B': 8, 'C': 9, 'F': 10, 'S': 11, 'Y': 12, '_': 13, 'a': 14, 'c': 15, 'd': 16, 'e': 17, 'f': 18, 'h': 19, 'i': 20, 'k': 21, 'l': 22, 'm': 23, 'n': 24, 'o': 25, 'p': 26, 'r': 27, 's': 28, 't': 29, 'u': 30, 'v': 31, 'w': 32, 'y': 33, 'z': 34}

# %%
x_numpy = []
y_numpy = []
temp_data = data

for t in range(len(temp_data) - context_size - 1):
    x_numpy.append(encoder(temp_data[t : t + context_size]))
    y_numpy.append(stoi[temp_data[t + context_size]])

x = torch.tensor(x_numpy, dtype=torch.long).to(device)
y = torch.tensor(y_numpy, dtype=torch.long).to(device)

N = x.shape[0]
train_ratio = 0.8
val_ratio = 0.1
test_ratio = 0.1

train_end = int(train_ratio * N)
val_end = int((train_ratio + val_ratio) * N)

x_train, y_train = x[:train_end], y[:train_end]
x_val, y_val = x[train_end:val_end], y[train_end:val_end]
x_test, y_test = x[val_end:], y[val_end:]

x, y = x.to(device), y.to(device)

batch_size = min(batch_size, x.shape[0])

# %%
# from torch import nn
# import torch.optim as optim
# _batch_size = 2
# _vocab_size = 100
# _embed_dim = 2
# embedding = nn.Embedding(_vocab_size, _embed_dim)
# x = torch.randint(0, 100, size=(_batch_size, 2), dtype=torch.long, generator=generator).to(device)
#
# emb = embedding(x)
# emb = emb.view(-1, _embed_dim)
#
# T = emb.shape[0]
# mat = torch.ones(T, T)
# upper = torch.tril(mat)
# upper = upper/upper.sum(1, keepdim=True)
# calc = upper @ emb
#
# # print(embedding)
# # print(x)
# # print(embedding(x))

# %%
from torch import nn
import torch.optim as optim

class Model(nn.Module):
    def __init__(self, embed_dim):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.register_buffer(
            "tril",
            torch.tril(torch.ones(context_size, context_size))
        )
        self.linear_1 = nn.Linear(embd_dim * context_size, vocab_size, bias=False)

    def forward(self, x_):
        B, T = x_.shape
        calc = self.embedding(x_)
        # emb = self.embedding(x_)
        # tril_mask = self.tril[:T, :T]
        # weights = tril_mask / tril_mask.sum(1, keepdim=True)
        # calc = weights @ emb
        # calc = calc.view(calc.size(0), -1)
        calc = calc.view(calc.size(0), -1)
        logits = self.linear_1(calc)
        return logits

# %%
loss = 0
criterion = nn.CrossEntropyLoss()
model = Model(embd_dim).to(device)

optimizer = optim.Adam(model.parameters(), lr=0.001)

lr_iterations = []
lr_losses = []
iteration_count = 0
model.train()
prev_weights = 0
for epoch in range(1000):

    idx = torch.randint(0, len(x_train), (batch_size,), device=device, generator=generator)
    rand_x = x_train[idx]
    rand_y = y_train[idx]

    optimizer.zero_grad(set_to_none=True)
    if prev_weights is not None:
        print('difference : ',model.linear_1.weight.detach().numpy()[0,0] - prev_weights)
    prev_weights = model.linear_1.weight.detach().numpy()[0,0]
    print('actual : ',prev_weights)

    outputs = model(rand_x)
    loss = criterion(outputs, rand_y)

    if epoch % 10000 == 0:
        print(loss.item())

    loss.backward()
    optimizer.step()
# Out:
# difference :  -0.01335901
# actual :  -0.01335901
# 3.744075059890747
# difference :  0.0009999946
# actual :  -0.012359016
# difference :  -0.000735214
# actual :  -0.01309423
# difference :  -0.00085430127
# actual :  -0.013948531
# difference :  -0.0008158479
# actual :  -0.014764379
# difference :  -0.00021369476
# actual :  -0.014978074
# difference :  0.0002758354
# actual :  -0.014702238
# difference :  0.0002286546
# actual :  -0.014473584
# difference :  0.00016161986
# actual :  -0.014311964
# difference :  0.00013760291
# actual :  -0.014174361
# difference :  0.000114184804
# actual :  -0.014060176
# difference :  7.83829e-05
# actual :  -0.013981793
# difference :  0.0001527518
# actual :  -0.013829041
# difference :  0.00013665576
# actual :  -0.0136923855
# difference :  9.4962306e-05
# actual :  -0.013597423
# difference :  3.512483e-05
# actual :  -0.013562298
# difference :  1.5271828e-05
# actual :  -0.013547027
# difference :  -1.7133541e-05
# actual :  -0.01356416
# difference :  0.00011142995
# actual :  -0.01345273
# difference :  8.413009e-05
# actual :  -0.0133686
# difference :  0.00018743891
# actual :  -0.013181161
# difference :  0.00013871212
# actual :  -0.013042449
# difference :  -1.986418e-05
# actual :  -0.013062313
# difference :  -5.4760836e-05
# actual :  -0.013117074
# difference :  -0.00013117306
# actual :  -0.013248247
# difference :  -0.00013433676
# actual :  -0.013382584
# difference :  -0.00025556423
# actual :  -0.013638148
# difference :  -0.00014346652
# actual :  -0.013781615
# difference :  -0.00016245153
# actual :  -0.013944066
# difference :  -0.00016112998
# actual :  -0.014105196
# difference :  -0.00015375577
# actual :  -0.014258952
# difference :  -0.00015397556
# actual :  -0.014412927
# difference :  -0.00016331766
# actual :  -0.014576245
# difference :  -0.00021167006
# actual :  -0.014787915
# difference :  -0.00019020773
# actual :  -0.014978123
# difference :  -0.00011222437
# actual :  -0.015090347
# difference :  -9.959936e-05
# actual :  -0.015189947
# difference :  -9.183213e-05
# actual :  -0.015281779
# difference :  -0.00012771226
# actual :  -0.015409491
# difference :  -0.00014447886
# actual :  -0.01555397
# difference :  -0.00014739297
# actual :  -0.015701363
# difference :  -0.00014769658
# actual :  -0.01584906
# difference :  -0.00013190508
# actual :  -0.015980965
# difference :  -0.0001329109
# actual :  -0.016113875
# difference :  -0.00014161505
# actual :  -0.01625549
# difference :  -0.00012243353
# actual :  -0.016377924
# difference :  -0.00017064065
# actual :  -0.016548565
# difference :  -0.00014860183
# actual :  -0.016697166
# difference :  -0.00017393567
# actual :  -0.016871102
# difference :  -0.0002225712
# actual :  -0.017093673
# difference :  -0.00021893531
# actual :  -0.017312609
# difference :  -0.00025146082
# actual :  -0.01756407
# difference :  -0.00026194006
# actual :  -0.01782601
# difference :  -7.4194744e-05
# actual :  -0.017900204
# difference :  -6.9020316e-05
# actual :  -0.017969225
# difference :  5.7617202e-05
# actual :  -0.017911607
# difference :  0.000111868605
# actual :  -0.017799739
# difference :  0.00010454096
# actual :  -0.017695198
# difference :  0.00017361157
# actual :  -0.017521586
# difference :  0.00033118203
# actual :  -0.017190404
# difference :  0.00027667172
# actual :  -0.016913733
# difference :  0.00029564835
# actual :  -0.016618084
# difference :  0.00038312003
# actual :  -0.016234964
# difference :  0.0004590992
# actual :  -0.015775865
# difference :  0.00044242106
# actual :  -0.015333444
# difference :  0.0003338307
# actual :  -0.014999613
# difference :  0.0002953196
# actual :  -0.014704294
# difference :  0.000341014
# actual :  -0.01436328
# difference :  0.000311126
# actual :  -0.014052154
# difference :  0.00031454302
# actual :  -0.013737611
# difference :  0.00029132608
# actual :  -0.013446284
# difference :  0.00037073158
# actual :  -0.013075553
# difference :  0.00022364687
# actual :  -0.012851906
# difference :  0.00022696983
# actual :  -0.012624936
# difference :  0.0002861647
# actual :  -0.0123387715
# difference :  0.00020362996
# actual :  -0.0121351415
# difference :  0.0001669405
# actual :  -0.011968201
# difference :  0.00016404316
# actual :  -0.011804158
# difference :  0.00013846904
# actual :  -0.011665689
# difference :  0.00013325736
# actual :  -0.0115324315
# difference :  0.00011003669
# actual :  -0.011422395
# difference :  9.8812394e-05
# actual :  -0.011323582
# difference :  7.271115e-05
# actual :  -0.011250871
# difference :  5.565677e-05
# actual :  -0.011195214
# difference :  9.540096e-05
# actual :  -0.0110998135
# difference :  8.408539e-05
# actual :  -0.011015728
# difference :  3.5057776e-05
# actual :  -0.01098067
# difference :  2.199877e-05
# actual :  -0.010958672
# difference :  2.0083971e-05
# actual :  -0.010938588
# difference :  7.148925e-05
# actual :  -0.010867098
# difference :  0.00011907052
# actual :  -0.010748028
# difference :  0.000105882995
# actual :  -0.010642145
# difference :  8.428283e-05
# actual :  -0.010557862
# difference :  4.9818307e-05
# actual :  -0.010508044
# difference :  2.9305927e-05
# actual :  -0.010478738
# difference :  2.1142885e-05
# actual :  -0.010457595
# difference :  3.467314e-06
# actual :  -0.010454128
# difference :  3.6465004e-05
# actual :  -0.010417663
# difference :  3.6070123e-05
# actual :  -0.010381592
# difference :  6.0687773e-05
# actual :  -0.010320905
# difference :  7.6160766e-05
# actual :  -0.010244744
# difference :  4.447531e-05
# actual :  -0.010200269
# difference :  -3.6275946e-05
# actual :  -0.010236545
# difference :  -4.9357302e-05
# actual :  -0.010285902
# difference :  -5.191285e-05
# actual :  -0.010337815
# difference :  -5.2372925e-05
# actual :  -0.010390188
# difference :  2.7673319e-05
# actual :  -0.010362514
# difference :  3.827922e-05
# actual :  -0.010324235
# difference :  1.5250407e-05
# actual :  -0.010308985
# difference :  7.4040145e-07
# actual :  -0.010308244
# difference :  -6.948318e-05
# actual :  -0.010377727
# difference :  -9.8981895e-05
# actual :  -0.010476709
# difference :  -9.7701326e-05
# actual :  -0.010574411
# difference :  -9.146426e-05
# actual :  -0.010665875
# difference :  -0.00010390673
# actual :  -0.010769782
# difference :  -9.9482015e-05
# actual :  -0.010869264
# difference :  -0.00012807641
# actual :  -0.01099734
# difference :  -0.00011728611
# actual :  -0.011114626
# difference :  -0.00013599452
# actual :  -0.011250621
# difference :  -0.00011504721
# actual :  -0.011365668
# difference :  -0.00011424068
# actual :  -0.011479909
# difference :  -0.000104820356
# actual :  -0.011584729
# difference :  -0.000105826184
# actual :  -0.011690555
# difference :  -5.9216283e-05
# actual :  -0.011749771
# difference :  -4.258752e-05
# actual :  -0.011792359
# difference :  -5.813781e-05
# actual :  -0.011850497
# difference :  -3.8502738e-05
# actual :  -0.0118889995
# difference :  -4.6555884e-05
# actual :  -0.011935555
# difference :  -4.34136e-05
# actual :  -0.011978969
# difference :  -4.1578896e-05
# actual :  -0.012020548
# difference :  -3.9505772e-05
# actual :  -0.012060054
# difference :  -3.908947e-05
# actual :  -0.012099143
# difference :  3.0705705e-06
# actual :  -0.012096073
# difference :  -1.33747235e-05
# actual :  -0.012109447
# difference :  -1.778733e-05
# actual :  -0.012127235
# difference :  -1.2726523e-05
# actual :  -0.012139961
# difference :  -1.447089e-05
# actual :  -0.012154432
# difference :  -1.9842759e-05
# actual :  -0.012174275
# difference :  1.6686507e-05
# actual :  -0.012157588
# difference :  1.5432015e-05
# actual :  -0.012142156
# difference :  4.226342e-06
# actual :  -0.01213793
# difference :  3.4859404e-06
# actual :  -0.012134444
# difference :  -2.9797666e-05
# actual :  -0.012164242
# difference :  -3.7275255e-05
# actual :  -0.012201517
# difference :  -3.594812e-05
# actual :  -0.012237465
# difference :  -4.4176355e-05
# actual :  -0.012281641
# difference :  -4.3164007e-05
# actual :  -0.012324805
# difference :  -3.9534643e-05
# actual :  -0.01236434
# difference :  -3.7840568e-05
# actual :  -0.012402181
# difference :  -4.5998953e-05
# actual :  -0.01244818
# difference :  -5.015917e-05
# actual :  -0.012498339
# difference :  -6.67423e-05
# actual :  -0.012565081
# difference :  1.5538186e-05
# actual :  -0.012549543
# difference :  1.9447878e-05
# actual :  -0.012530095
# difference :  1.3884157e-05
# actual :  -0.012516211
# difference :  -1.9306317e-05
# actual :  -0.012535517
# difference :  -3.1852163e-05
# actual :  -0.012567369
# difference :  -5.3407624e-05
# actual :  -0.012620777
# difference :  -6.598979e-05
# actual :  -0.012686767
# difference :  -6.223004e-05
# actual :  -0.012748997
# difference :  -5.02849e-05
# actual :  -0.012799282
# difference :  -4.6843663e-05
# actual :  -0.012846125
# difference :  -3.0593015e-05
# actual :  -0.012876718
# difference :  -3.4585595e-05
# actual :  -0.012911304
# difference :  -4.0317886e-05
# actual :  -0.012951622
# difference :  -2.4334528e-05
# actual :  -0.012975956
# difference :  -2.5522895e-05
# actual :  -0.013001479
# difference :  -4.601199e-05
# actual :  -0.013047491
# difference :  -4.1669235e-05
# actual :  -0.01308916
# difference :  -3.9388426e-05
# actual :  -0.013128549
# difference :  -7.1427785e-05
# actual :  -0.013199977
# difference :  -6.870832e-05
# actual :  -0.013268685
# difference :  -5.7513826e-05
# actual :  -0.013326199
# difference :  -5.4395758e-05
# actual :  -0.013380595
# difference :  -6.693043e-05
# actual :  -0.013447525
# difference :  -6.300397e-05
# actual :  -0.013510529
# difference :  -6.055273e-05
# actual :  -0.013571082
# difference :  -8.415617e-05
# actual :  -0.013655238
# difference :  -7.544365e-05
# actual :  -0.0137306815
# difference :  -9.9446625e-05
# actual :  -0.013830128
# difference :  -9.1524795e-05
# actual :  -0.013921653
# difference :  -8.4646046e-05
# actual :  -0.014006299
# difference :  -4.257541e-05
# actual :  -0.014048874
# difference :  -6.537046e-05
# actual :  -0.014114245
# difference :  -6.007403e-05
# actual :  -0.014174319
# difference :  -6.595347e-05
# actual :  -0.014240272
# difference :  -7.6701865e-05
# actual :  -0.014316974
# difference :  -7.908512e-05
# actual :  -0.014396059
# difference :  -9.423029e-05
# actual :  -0.01449029
# difference :  -7.547904e-05
# actual :  -0.014565769
# difference :  -7.9300255e-05
# actual :  -0.014645069
# difference :  -7.4822456e-05
# actual :  -0.014719891
# difference :  -7.060543e-05
# actual :  -0.014790497
# difference :  -4.843902e-05
# actual :  -0.014838936
# difference :  2.503395e-05
# actual :  -0.014813902
# difference :  1.944229e-05
# actual :  -0.01479446
# difference :  1.7725863e-05
# actual :  -0.014776734
# difference :  2.1037646e-05
# actual :  -0.014755696
# difference :  1.0498799e-05
# actual :  -0.014745197
# difference :  8.426607e-06
# actual :  -0.014736771
# difference :  -1.8185936e-05
# actual :  -0.014754957
# difference :  4.4048764e-05
# actual :  -0.014710908
# difference :  3.0112453e-05
# actual :  -0.014680795
# difference :  2.2220425e-05
# actual :  -0.014658575
# difference :  7.1153045e-07
# actual :  -0.014657863
# difference :  -1.3447367e-05
# actual :  -0.014671311
# difference :  -9.0785325e-06
# actual :  -0.014680389
# difference :  -8.601695e-06
# actual :  -0.014688991
# difference :  -8.707866e-06
# actual :  -0.014697699
# difference :  -4.0723942e-05
# actual :  -0.014738423
# difference :  -3.906153e-05
# actual :  -0.014777484
# difference :  -3.551133e-05
# actual :  -0.014812996
# difference :  -4.4664368e-05
# actual :  -0.01485766
# difference :  -3.9055012e-05
# actual :  -0.014896715
# difference :  -4.290603e-05
# actual :  -0.014939621
# difference :  -5.743932e-05
# actual :  -0.01499706
# difference :  -5.391799e-05
# actual :  -0.015050978
# difference :  -5.8062375e-05
# actual :  -0.015109041
# difference :  -6.455742e-05
# actual :  -0.015173598
# difference :  -6.271154e-05
# actual :  -0.01523631
# difference :  -4.27356e-05
# actual :  -0.015279045
# difference :  -4.307367e-05
# actual :  -0.015322119
# difference :  -4.059542e-05
# actual :  -0.015362714
# difference :  -3.7446618e-05
# actual :  -0.015400161
# difference :  -4.5319088e-05
# actual :  -0.01544548
# difference :  -3.7979335e-05
# actual :  -0.015483459
# difference :  -3.0636787e-05
# actual :  -0.015514096
# difference :  -5.1711686e-05
# actual :  -0.015565808
# difference :  -5.3779222e-05
# actual :  -0.015619587
# difference :  -1.4053658e-06
# actual :  -0.0156209925
# difference :  -1.5114434e-05
# actual :  -0.015636107
# difference :  2.8854236e-05
# actual :  -0.015607253
# difference :  2.6049092e-05
# actual :  -0.015581204
# difference :  1.9231811e-05
# actual :  -0.015561972
# difference :  1.6915612e-05
# actual :  -0.015545056
# difference :  1.7865561e-05
# actual :  -0.015527191
# difference :  2.8598122e-05
# actual :  -0.0154985925
# difference :  2.3888424e-05
# actual :  -0.015474704
# difference :  3.8966537e-06
# actual :  -0.015470807
# difference :  -1.2025237e-05
# actual :  -0.015482833
# difference :  2.9513612e-05
# actual :  -0.015453319
# difference :  2.8056093e-05
# actual :  -0.015425263
# difference :  2.6077963e-05
# actual :  -0.015399185
# difference :  2.0584092e-05
# actual :  -0.015378601
# difference :  1.6205944e-05
# actual :  -0.015362395
# difference :  1.5182421e-05
# actual :  -0.015347213
# difference :  1.4397316e-05
# actual :  -0.015332815
# difference :  6.500166e-05
# actual :  -0.015267814
# difference :  5.8174133e-05
# actual :  -0.015209639
# difference :  5.2428804e-05
# actual :  -0.015157211
# difference :  4.72283e-05
# actual :  -0.015109982
# difference :  4.4099987e-05
# actual :  -0.015065882
# difference :  3.9611943e-05
# actual :  -0.01502627
# difference :  3.2163225e-05
# actual :  -0.014994107
# difference :  2.6877038e-05
# actual :  -0.01496723
# difference :  1.7177314e-05
# actual :  -0.014950053
# difference :  2.5348738e-05
# actual :  -0.014924704
# difference :  2.1867454e-05
# actual :  -0.014902837
# difference :  2.9087067e-05
# actual :  -0.01487375
# difference :  3.337767e-05
# actual :  -0.014840372
# difference :  1.6069971e-05
# actual :  -0.014824302
# difference :  4.3993816e-05
# actual :  -0.014780308
# difference :  3.6529265e-05
# actual :  -0.014743779
# difference :  3.208127e-05
# actual :  -0.014711698
# difference :  2.7292408e-05
# actual :  -0.014684405
# difference :  7.5800344e-06
# actual :  -0.014676825
# difference :  4.7443435e-05
# actual :  -0.014629382
# difference :  4.3530017e-05
# actual :  -0.014585852
# difference :  3.4740195e-05
# actual :  -0.0145511115
# difference :  1.7452054e-05
# actual :  -0.014533659
# difference :  8.477829e-06
# actual :  -0.014525182
# difference :  6.854534e-06
# actual :  -0.014518327
# difference :  5.7490543e-06
# actual :  -0.014512578
# difference :  -8.2068145e-06
# actual :  -0.014520785
# difference :  -1.0586344e-05
# actual :  -0.014531371
# difference :  -1.7439015e-05
# actual :  -0.01454881
# difference :  -2.4090521e-05
# actual :  -0.014572901
# difference :  1.3751909e-05
# actual :  -0.014559149
# difference :  8.492731e-06
# actual :  -0.014550656
# difference :  -1.3315119e-05
# actual :  -0.014563971
# difference :  -1.662504e-05
# actual :  -0.014580596
# difference :  1.0786578e-05
# actual :  -0.01456981
# difference :  2.4400651e-06
# actual :  -0.01456737
# difference :  9.3877316e-07
# actual :  -0.014566431
# difference :  4.004687e-08
# actual :  -0.014566391
# difference :  8.8848174e-07
# actual :  -0.014565502
# difference :  2.4937093e-05
# actual :  -0.014540565
# difference :  2.0219944e-05
# actual :  -0.014520345
# difference :  5.752407e-05
# actual :  -0.014462821
# difference :  4.719384e-05
# actual :  -0.014415627
# difference :  4.0733255e-05
# actual :  -0.014374894
# difference :  3.5945326e-05
# actual :  -0.014338949
# difference :  2.936367e-05
# actual :  -0.014309585
# difference :  2.4288893e-05
# actual :  -0.014285296
# difference :  2.080854e-05
# actual :  -0.014264488
# difference :  3.4163706e-05
# actual :  -0.014230324
# difference :  2.9454008e-05
# actual :  -0.01420087
# difference :  2.5095418e-05
# actual :  -0.0141757745
# difference :  6.28056e-05
# actual :  -0.014112969
# difference :  5.5423938e-05
# actual :  -0.014057545
# difference :  4.0727668e-05
# actual :  -0.014016817
# difference :  3.7041493e-05
# actual :  -0.013979776
# difference :  3.3224e-05
# actual :  -0.013946552
# difference :  1.6500242e-05
# actual :  -0.013930052
# difference :  1.4066696e-05
# actual :  -0.013915985
# difference :  2.165977e-05
# actual :  -0.013894325
# difference :  1.7073937e-05
# actual :  -0.013877251
# difference :  1.3548881e-05
# actual :  -0.013863702
# difference :  3.905967e-05
# actual :  -0.013824643
# difference :  3.437791e-05
# actual :  -0.013790265
# difference :  2.9639341e-05
# actual :  -0.013760625
# difference :  2.7626753e-05
# actual :  -0.013732999
# difference :  4.437659e-05
# actual :  -0.013688622
# difference :  3.2457523e-05
# actual :  -0.0136561645
# difference :  2.8029084e-05
# actual :  -0.013628135
# difference :  1.1352822e-05
# actual :  -0.013616783
# difference :  8.92207e-06
# actual :  -0.013607861
# difference :  3.1683594e-06
# actual :  -0.013604692
# difference :  5.029142e-06
# actual :  -0.013599663
# difference :  4.2626634e-06
# actual :  -0.0135954
# difference :  1.7909333e-06
# actual :  -0.013593609
# difference :  -2.7939677e-09
# actual :  -0.013593612
# difference :  2.6170164e-07
# actual :  -0.013593351
# difference :  1.1650845e-06
# actual :  -0.013592185
# difference :  2.5890768e-07
# actual :  -0.013591927
# difference :  1.868233e-05
# actual :  -0.013573244
# difference :  1.6205013e-05
# actual :  -0.013557039
# difference :  1.1296943e-05
# actual :  -0.013545742
# difference :  4.5076013e-06
# actual :  -0.013541235
# difference :  3.5641715e-06
# actual :  -0.0135376705
# difference :  2.2398308e-06
# actual :  -0.013535431
# difference :  -7.933006e-06
# actual :  -0.013543364
# difference :  -8.974224e-06
# actual :  -0.013552338
# difference :  -6.129034e-06
# actual :  -0.013558467
# difference :  -7.5921416e-06
# actual :  -0.013566059
# difference :  -9.516254e-06
# actual :  -0.013575575
# difference :  -1.0443851e-05
# actual :  -0.013586019
# difference :  -1.0214746e-05
# actual :  -0.013596234
# difference :  -7.5334683e-06
# actual :  -0.013603767
# difference :  6.2175095e-06
# actual :  -0.01359755
# difference :  3.349036e-06
# actual :  -0.013594201
# difference :  -1.0433607e-05
# actual :  -0.013604634
# difference :  -1.0011718e-05
# actual :  -0.013614646
# difference :  -1.818873e-05
# actual :  -0.013632835
# difference :  -1.6599894e-05
# actual :  -0.013649435
# difference :  -4.5942143e-06
# actual :  -0.013654029
# difference :  -5.655922e-06
# actual :  -0.013659685
# difference :  -5.867332e-06
# actual :  -0.013665552
# difference :  -3.0267984e-06
# actual :  -0.013668579
# difference :  -1.27526e-05
# actual :  -0.013681332
# difference :  -1.27423555e-05
# actual :  -0.013694074
# difference :  -9.560958e-06
# actual :  -0.013703635
# difference :  -1.169648e-05
# actual :  -0.013715331
# difference :  -1.3109297e-05
# actual :  -0.013728441
# difference :  3.6135316e-06
# actual :  -0.013724827
# difference :  1.1816621e-05
# actual :  -0.013713011
# difference :  1.46161765e-05
# actual :  -0.013698394
# difference :  7.374212e-06
# actual :  -0.01369102
# difference :  6.482005e-06
# actual :  -0.013684538
# difference :  -4.945323e-06
# actual :  -0.0136894835
# difference :  -7.71042e-06
# actual :  -0.013697194
# difference :  -1.9113533e-05
# actual :  -0.0137163075
# difference :  -1.759082e-05
# actual :  -0.013733898
# difference :  -1.6564503e-05
# actual :  -0.013750463
# difference :  -1.5784055e-05
# actual :  -0.013766247
# difference :  9.343028e-06
# actual :  -0.013756904
# difference :  -9.667128e-07
# actual :  -0.0137578705
# difference :  -2.4111941e-06
# actual :  -0.013760282
# difference :  -9.001233e-06
# actual :  -0.013769283
# difference :  -9.888783e-06
# actual :  -0.013779172
# difference :  3.144145e-06
# actual :  -0.013776028
# difference :  1.0937452e-05
# actual :  -0.01376509
# difference :  2.5994144e-05
# actual :  -0.013739096
# difference :  2.3376197e-05
# actual :  -0.01371572
# difference :  4.9781054e-05
# actual :  -0.013665939
# difference :  3.6140904e-05
# actual :  -0.013629798
# difference :  3.057625e-05
# actual :  -0.013599222
# difference :  2.1384098e-05
# actual :  -0.0135778375
# difference :  2.7640723e-05
# actual :  -0.013550197
# difference :  2.6183203e-05
# actual :  -0.013524014
# difference :  2.2481196e-05
# actual :  -0.013501532
# difference :  2.3303553e-05
# actual :  -0.013478229
# difference :  2.1051615e-05
# actual :  -0.013457177
# difference :  1.9186176e-05
# actual :  -0.013437991
# difference :  1.0900199e-05
# actual :  -0.013427091
# difference :  9.518117e-06
# actual :  -0.013417573
# difference :  2.1503307e-05
# actual :  -0.013396069
# difference :  1.729466e-05
# actual :  -0.013378775
# difference :  1.998432e-05
# actual :  -0.01335879
# difference :  3.148429e-05
# actual :  -0.013327306
# difference :  2.4602748e-05
# actual :  -0.013302703
# difference :  2.1825545e-05
# actual :  -0.013280878
# difference :  1.0814518e-05
# actual :  -0.013270063
# difference :  4.241243e-06
# actual :  -0.013265822
# difference :  3.9571896e-06
# actual :  -0.013261865
# difference :  -5.239621e-06
# actual :  -0.0132671045
# difference :  -5.8850273e-06
# actual :  -0.01327299
# difference :  -5.0514936e-06
# actual :  -0.013278041
# difference :  2.223067e-05
# actual :  -0.01325581
# difference :  2.0666048e-05
# actual :  -0.013235144
# difference :  4.4164248e-05
# actual :  -0.01319098
# difference :  4.3203123e-05
# actual :  -0.013147777
# difference :  3.7212856e-05
# actual :  -0.013110564
# difference :  3.4508295e-05
# actual :  -0.013076056
# difference :  3.88762e-05
# actual :  -0.01303718
# difference :  3.2844022e-05
# actual :  -0.013004336
# difference :  2.4507754e-05
# actual :  -0.012979828
# difference :  1.1805445e-05
# actual :  -0.012968022
# difference :  1.36606395e-05
# actual :  -0.012954362
# difference :  2.0908192e-05
# actual :  -0.012933454
# difference :  1.48154795e-05
# actual :  -0.012918638
# difference :  1.23325735e-05
# actual :  -0.0129063055
# difference :  1.0260381e-05
# actual :  -0.012896045
# difference :  3.6365353e-05
# actual :  -0.01285968
# difference :  3.251899e-05
# actual :  -0.012827161
# difference :  3.2140873e-05
# actual :  -0.01279502
# difference :  4.253816e-05
# actual :  -0.012752482
# difference :  3.2910146e-05
# actual :  -0.012719572
# difference :  3.253948e-05
# actual :  -0.012687032
# difference :  2.6769936e-05
# actual :  -0.012660262
# difference :  3.7034974e-05
# actual :  -0.012623227
# difference :  2.9217452e-05
# actual :  -0.01259401
# difference :  2.4362467e-05
# actual :  -0.012569647
# difference :  2.533663e-05
# actual :  -0.012544311
# difference :  2.1482818e-05
# actual :  -0.012522828
# difference :  2.3738481e-05
# actual :  -0.012499089
# difference :  2.1595508e-05
# actual :  -0.012477494
# difference :  2.6149675e-05
# actual :  -0.012451344
# difference :  2.3119152e-05
# actual :  -0.012428225
# difference :  1.30860135e-05
# actual :  -0.012415139
# difference :  1.0186806e-05
# actual :  -0.012404952
# difference :  3.164448e-05
# actual :  -0.012373308
# difference :  2.731476e-05
# actual :  -0.012345993
# difference :  2.1232292e-05
# actual :  -0.012324761
# difference :  1.1442229e-05
# actual :  -0.012313318
# difference :  6.28829e-06
# actual :  -0.01230703
# difference :  4.8838556e-06
# actual :  -0.012302146
# difference :  3.4766272e-06
# actual :  -0.01229867
# difference :  2.4866313e-05
# actual :  -0.012273803
# difference :  2.3256056e-05
# actual :  -0.012250547
# difference :  2.763234e-05
# actual :  -0.012222915
# difference :  1.8516555e-05
# actual :  -0.012204398
# difference :  1.2759119e-05
# actual :  -0.012191639
# difference :  5.4789707e-06
# actual :  -0.01218616
# difference :  1.1431053e-05
# actual :  -0.012174729
# difference :  1.1024997e-05
# actual :  -0.012163704
# difference :  4.835427e-06
# actual :  -0.012158869
# difference :  2.3585744e-05
# actual :  -0.012135283
# difference :  2.1562912e-05
# actual :  -0.01211372
# difference :  1.7925166e-05
# actual :  -0.012095795
# difference :  1.2493692e-05
# actual :  -0.012083301
# difference :  9.800307e-06
# actual :  -0.012073501
# difference :  2.800487e-06
# actual :  -0.0120707005
# difference :  6.06291e-07
# actual :  -0.012070094
# difference :  -1.1986122e-06
# actual :  -0.012071293
# difference :  -4.8689544e-06
# actual :  -0.012076162
# difference :  -5.6056306e-06
# actual :  -0.012081767
# difference :  -4.5290217e-06
# actual :  -0.012086296
# difference :  7.2633848e-06
# actual :  -0.012079033
# difference :  2.9101968e-05
# actual :  -0.012049931
# difference :  2.6225112e-05
# actual :  -0.012023706
# difference :  2.2261404e-05
# actual :  -0.012001445
# difference :  1.9393861e-05
# actual :  -0.011982051
# difference :  1.6973354e-05
# actual :  -0.011965077
# difference :  1.3560057e-05
# actual :  -0.011951517
# difference :  1.0476448e-05
# actual :  -0.011941041
# difference :  2.1656975e-05
# actual :  -0.011919384
# difference :  1.6472302e-05
# actual :  -0.011902912
# difference :  1.3872981e-05
# actual :  -0.011889039
# difference :  1.225248e-05
# actual :  -0.011876786
# difference :  2.197083e-05
# actual :  -0.011854815
# difference :  1.7792918e-05
# actual :  -0.011837022
# difference :  1.4946796e-05
# actual :  -0.011822076
# difference :  3.0386262e-05
# actual :  -0.011791689
# difference :  2.901908e-05
# actual :  -0.01176267
# difference :  2.2055581e-05
# actual :  -0.011740615
# difference :  7.7476725e-06
# actual :  -0.011732867
# difference :  1.7444603e-05
# actual :  -0.011715422
# difference :  1.554098e-05
# actual :  -0.011699881
# difference :  1.1627562e-05
# actual :  -0.011688254
# difference :  1.0855496e-05
# actual :  -0.011677398
# difference :  1.2612902e-05
# actual :  -0.011664785
# difference :  3.4496188e-06
# actual :  -0.011661336
# difference :  -5.636364e-06
# actual :  -0.011666972
# difference :  -5.055219e-06
# actual :  -0.011672027
# difference :  2.915971e-06
# actual :  -0.011669111
# difference :  7.5018033e-06
# actual :  -0.01166161
# difference :  2.413988e-06
# actual :  -0.011659196
# difference :  1.8044375e-05
# actual :  -0.011641151
# difference :  1.1733733e-05
# actual :  -0.011629418
# difference :  2.5671907e-05
# actual :  -0.011603746
# difference :  2.2163615e-05
# actual :  -0.011581582
# difference :  2.049841e-05
# actual :  -0.011561084
# difference :  1.776591e-05
# actual :  -0.011543318
# difference :  1.4226884e-05
# actual :  -0.011529091
# difference :  1.1890195e-05
# actual :  -0.011517201
# difference :  1.9087456e-05
# actual :  -0.011498113
# difference :  1.732912e-05
# actual :  -0.011480784
# difference :  1.0404736e-05
# actual :  -0.011470379
# difference :  7.573515e-06
# actual :  -0.011462806
# difference :  1.8178485e-05
# actual :  -0.011444627
# difference :  1.7079525e-05
# actual :  -0.011427548
# difference :  7.448718e-06
# actual :  -0.011420099
# difference :  6.3907355e-06
# actual :  -0.011413708
# difference :  7.172115e-06
# actual :  -0.011406536
# difference :  5.248934e-06
# actual :  -0.011401287
# difference :  4.775822e-06
# actual :  -0.011396511
# difference :  1.6586855e-06
# actual :  -0.011394853
# difference :  -1.1567026e-06
# actual :  -0.0113960095
# difference :  -1.0763295e-05
# actual :  -0.011406773
# difference :  -9.7109005e-06
# actual :  -0.011416484
# difference :  -9.2172995e-06
# actual :  -0.011425701
# difference :  -8.751638e-06
# actual :  -0.011434453
# difference :  -9.264797e-06
# actual :  -0.011443717
# difference :  -7.4161217e-06
# actual :  -0.0114511335
# difference :  -1.220312e-05
# actual :  -0.011463337
# difference :  -1.3197772e-05
# actual :  -0.011476534
# difference :  -1.5840866e-05
# actual :  -0.011492375
# difference :  -1.1409633e-05
# actual :  -0.011503785
# difference :  -1.087971e-05
# actual :  -0.011514665
# difference :  -9.292737e-06
# actual :  -0.011523957
# difference :  -8.8158995e-06
# actual :  -0.011532773
# difference :  -5.7360157e-06
# actual :  -0.011538509
# difference :  -7.448718e-06
# actual :  -0.011545958
# difference :  -7.751398e-06
# actual :  -0.011553709
# difference :  -7.2624534e-06
# actual :  -0.011560972
# difference :  -7.4412674e-07
# actual :  -0.011561716
# difference :  -2.658926e-06
# actual :  -0.011564375
# difference :  -1.6642734e-06
# actual :  -0.011566039
# difference :  8.707866e-06
# actual :  -0.011557331
# difference :  6.883405e-06
# actual :  -0.011550448
# difference :  5.8859587e-06
# actual :  -0.011544562
# difference :  5.8645383e-06
# actual :  -0.011538697
# difference :  3.383495e-06
# actual :  -0.011535314
# difference :  5.283393e-06
# actual :  -0.0115300305
# difference :  4.6100467e-06
# actual :  -0.0115254205
# difference :  4.63333e-06
# actual :  -0.011520787
# difference :  -5.569309e-07
# actual :  -0.011521344
# difference :  -2.9290095e-06
# actual :  -0.011524273
# difference :  -4.096888e-06
# actual :  -0.01152837
# difference :  -2.8312206e-07
# actual :  -0.011528653
# difference :  3.0640513e-07
# actual :  -0.011528347
# difference :  4.2654574e-07
# actual :  -0.01152792
# difference :  5.101785e-06
# actual :  -0.011522818
# difference :  1.3327226e-06
# actual :  -0.011521486
# difference :  -5.3364784e-07
# actual :  -0.011522019
# difference :  -1.5841797e-06
# actual :  -0.011523603
# difference :  7.821247e-06
# actual :  -0.011515782
# difference :  6.565824e-06
# actual :  -0.011509216
# difference :  5.6056306e-06
# actual :  -0.011503611
# difference :  -2.1411106e-06
# actual :  -0.011505752
# difference :  -1.6652048e-06
# actual :  -0.011507417
# difference :  -2.5313348e-06
# actual :  -0.011509948
# difference :  -1.8943101e-06
# actual :  -0.011511843
# difference :  -1.9557774e-07
# actual :  -0.011512038
# difference :  -2.8144568e-06
# actual :  -0.011514853
# difference :  -4.260801e-06
# actual :  -0.011519114
# difference :  -5.99958e-06
# actual :  -0.011525113
# difference :  5.092472e-06
# actual :  -0.011520021
# difference :  1.40098855e-05
# actual :  -0.011506011
# difference :  1.6216189e-05
# actual :  -0.011489795
# difference :  1.4328398e-05
# actual :  -0.011475466
# difference :  1.3160519e-05
# actual :  -0.011462306
# difference :  1.3916753e-05
# actual :  -0.011448389
# difference :  1.1424534e-05
# actual :  -0.011436964
# difference :  9.356998e-06
# actual :  -0.011427607
# difference :  5.500391e-06
# actual :  -0.011422107
# difference :  -2.543442e-06
# actual :  -0.01142465
# difference :  -3.6219135e-06
# actual :  -0.011428272
# difference :  -2.8098002e-06
# actual :  -0.011431082
# difference :  -5.901791e-06
# actual :  -0.011436984
# difference :  -1.15875155e-05
# actual :  -0.011448571
# difference :  -1.1095777e-05
# actual :  -0.011459667
# difference :  -4.922971e-06
# actual :  -0.01146459
# difference :  -6.73905e-06
# actual :  -0.011471329
# difference :  -7.3313713e-06
# actual :  -0.011478661
# difference :  -8.49925e-06
# actual :  -0.01148716
# difference :  -8.063391e-06
# actual :  -0.011495223
# difference :  -8.8764355e-06
# actual :  -0.0115041
# difference :  -7.903203e-06
# actual :  -0.011512003
# difference :  -7.113442e-06
# actual :  -0.011519116
# difference :  -6.395392e-06
# actual :  -0.011525512
# difference :  -1.3848767e-05
# actual :  -0.0115393605
# difference :  -7.058494e-06
# actual :  -0.011546419
# difference :  -7.426366e-06
# actual :  -0.011553845
# difference :  -6.7837536e-06
# actual :  -0.011560629
# difference :  -8.16863e-06
# actual :  -0.011568798
# difference :  -1.899153e-05
# actual :  -0.011587789
# difference :  -1.717452e-05
# actual :  -0.011604964
# difference :  -1.3725832e-05
# actual :  -0.01161869
# difference :  -1.4591031e-05
# actual :  -0.011633281
# difference :  -1.1103228e-05
# actual :  -0.011644384
# difference :  -1.6508624e-05
# actual :  -0.0116608925
# difference :  -1.5291385e-05
# actual :  -0.011676184
# difference :  -1.6897917e-05
# actual :  -0.011693082
# difference :  -1.6712584e-05
# actual :  -0.011709794
# difference :  -1.542829e-05
# actual :  -0.011725223
# difference :  -1.3875775e-05
# actual :  -0.0117390985
# difference :  -6.5555796e-06
# actual :  -0.011745654
# difference :  -5.8021396e-06
# actual :  -0.011751456
# difference :  -8.1546605e-06
# actual :  -0.011759611
# difference :  -1.0927208e-05
# actual :  -0.011770538
# difference :  -1.1543743e-05
# actual :  -0.011782082
# difference :  -1.06059015e-05
# actual :  -0.011792688
# difference :  -1.0620803e-05
# actual :  -0.0118033085
# difference :  -6.827526e-06
# actual :  -0.011810136
# difference :  -1.2058765e-05
# actual :  -0.011822195
# difference :  -3.051944e-06
# actual :  -0.011825247
# difference :  -3.4924597e-06
# actual :  -0.011828739
# difference :  -6.1662868e-06
# actual :  -0.0118349055
# difference :  -7.000752e-06
# actual :  -0.011841906
# difference :  -8.544885e-06
# actual :  -0.011850451
# difference :  -1.0619871e-05
# actual :  -0.011861071
# difference :  -1.0079704e-05
# actual :  -0.011871151
# difference :  3.0323863e-06
# actual :  -0.011868118
# difference :  -4.94346e-06
# actual :  -0.011873062
# difference :  -9.608455e-06
# actual :  -0.01188267
# difference :  -9.030104e-06
# actual :  -0.0118917
# difference :  5.927868e-06
# actual :  -0.011885772
# difference :  4.7944486e-06
# actual :  -0.011880978
# difference :  7.059425e-07
# actual :  -0.011880272
# difference :  -7.2736293e-07
# actual :  -0.011880999
# difference :  -7.631257e-06
# actual :  -0.011888631
# difference :  -7.339753e-06
# actual :  -0.01189597
# difference :  -7.6210126e-06
# actual :  -0.011903591
# difference :  -8.838251e-06
# actual :  -0.01191243
# difference :  -7.151626e-06
# actual :  -0.011919581
# difference :  2.9066578e-06
# actual :  -0.011916675
# difference :  1.2262724e-05
# actual :  -0.011904412
# difference :  6.0321763e-06
# actual :  -0.01189838
# difference :  5.3886324e-06
# actual :  -0.011892991
# difference :  2.6095659e-06
# actual :  -0.011890382
# difference :  3.0016527e-06
# actual :  -0.01188738
# difference :  1.8384308e-06
# actual :  -0.0118855415
# difference :  -4.278496e-06
# actual :  -0.01188982
# difference :  -5.32344e-06
# actual :  -0.011895143
# difference :  -4.484318e-06
# actual :  -0.011899628
# difference :  3.525056e-06
# actual :  -0.011896103
# difference :  2.794899e-06
# actual :  -0.011893308
# difference :  8.419156e-07
# actual :  -0.011892466
# difference :  -7.79517e-07
# actual :  -0.011893245
# difference :  -1.12093985e-05
# actual :  -0.011904455
# difference :  -6.192364e-06
# actual :  -0.011910647
# difference :  5.046837e-06
# actual :  -0.0119056
# difference :  -2.7250499e-06
# actual :  -0.011908325
# difference :  -1.0235235e-05
# actual :  -0.011918561
# difference :  -9.790994e-06
# actual :  -0.011928352
# difference :  -3.9599836e-06
# actual :  -0.011932312
# difference :  -4.088506e-06
# actual :  -0.0119364
# difference :  -1.530163e-06
# actual :  -0.01193793
# difference :  -9.881333e-07
# actual :  -0.011938918
# difference :  -1.6232952e-06
# actual :  -0.011940542
# difference :  2.8312206e-07
# actual :  -0.011940259
# difference :  -1.7657876e-06
# actual :  -0.011942024
# difference :  2.427958e-06
# actual :  -0.011939596
# difference :  1.5940517e-05
# actual :  -0.011923656
# difference :  1.2965873e-05
# actual :  -0.01191069
# difference :  2.4225563e-05
# actual :  -0.011886464
# difference :  1.4767982e-05
# actual :  -0.011871696
# difference :  6.4391643e-06
# actual :  -0.011865257
# difference :  -1.8626451e-08
# actual :  -0.011865276
# difference :  -1.0244548e-08
# actual :  -0.011865286
# difference :  -1.8905848e-07
# actual :  -0.011865475
# difference :  -6.2584877e-06
# actual :  -0.011871734
# difference :  -5.8338046e-06
# actual :  -0.0118775675
# difference :  5.2619725e-07
# actual :  -0.011877041
# difference :  5.3057447e-06
# actual :  -0.011871736
# difference :  -5.6205317e-06
# actual :  -0.011877356
# difference :  -6.3851476e-06
# actual :  -0.011883741
# difference :  -1.0194257e-05
# actual :  -0.0118939355
# difference :  -1.06636435e-05
# actual :  -0.011904599
# difference :  -1.1638738e-05
# actual :  -0.011916238
# difference :  -1.4916994e-05
# actual :  -0.011931155
# difference :  -4.5001507e-06
# actual :  -0.011935655
# difference :  -8.108094e-06
# actual :  -0.011943763
# difference :  -5.609356e-06
# actual :  -0.0119493725
# difference :  8.7842345e-06
# actual :  -0.011940588
# difference :  8.021481e-06
# actual :  -0.011932567
# difference :  1.1241063e-06
# actual :  -0.011931443
# difference :  2.1704473e-05
# actual :  -0.011909738
# difference :  1.9112602e-05
# actual :  -0.011890626
# difference :  2.2307038e-05
# actual :  -0.011868319
# difference :  1.7182902e-05
# actual :  -0.011851136
# difference :  1.333002e-05
# actual :  -0.011837806
# difference :  7.4673444e-06
# actual :  -0.011830338
# difference :  1.1348166e-05
# actual :  -0.01181899
# difference :  6.6701323e-06
# actual :  -0.01181232
# difference :  5.728565e-06
# actual :  -0.011806591
# difference :  4.142523e-06
# actual :  -0.011802449
# difference :  1.14720315e-05
# actual :  -0.011790977
# difference :  7.817522e-06
# actual :  -0.011783159
# difference :  7.0929527e-06
# actual :  -0.011776066
# difference :  2.8312206e-06
# actual :  -0.011773235
# difference :  3.0044466e-06
# actual :  -0.011770231
# difference :  2.4763867e-06
# actual :  -0.011767754
# difference :  1.963228e-06
# actual :  -0.011765791
# difference :  -4.402362e-06
# actual :  -0.011770193
# difference :  -4.78141e-06
# actual :  -0.011774975
# difference :  -6.04894e-06
# actual :  -0.011781024
# difference :  -1.6996637e-06
# actual :  -0.0117827235
# difference :  -3.7429854e-06
# actual :  -0.011786466
# difference :  -5.4091215e-06
# actual :  -0.011791876
# difference :  -4.838221e-06
# actual :  -0.011796714
# difference :  -4.391186e-06
# actual :  -0.011801105
# difference :  -5.393289e-06
# actual :  -0.011806498
# difference :  -7.4133277e-06
# actual :  -0.011813912
# difference :  -6.7232177e-06
# actual :  -0.011820635
# difference :  -6.461516e-06
# actual :  -0.011827096
# difference :  -1.4636666e-05
# actual :  -0.011841733
# difference :  -5.3681433e-06
# actual :  -0.011847101
# difference :  1.2665987e-06
# actual :  -0.011845835
# difference :  -3.6228448e-07
# actual :  -0.011846197
# difference :  4.5336783e-06
# actual :  -0.011841663
# difference :  3.8016587e-06
# actual :  -0.0118378615
# difference :  1.4978461e-05
# actual :  -0.011822883
# difference :  1.3221055e-05
# actual :  -0.011809662
# difference :  1.843553e-05
# actual :  -0.011791226
# difference :  1.593586e-05
# actual :  -0.011775291
# difference :  1.7348677e-05
# actual :  -0.011757942
# difference :  1.3305806e-05
# actual :  -0.011744636
# difference :  1.2183562e-05
# actual :  -0.011732453
# difference :  8.584e-06
# actual :  -0.011723869
# difference :  7.197261e-06
# actual :  -0.011716671
# difference :  1.5862286e-05
# actual :  -0.011700809
# difference :  2.4161302e-05
# actual :  -0.011676648
# difference :  2.2451393e-05
# actual :  -0.011654196
# difference :  2.2453256e-05
# actual :  -0.011631743
# difference :  1.8912368e-05
# actual :  -0.011612831
# difference :  1.6728416e-05
# actual :  -0.011596102
# difference :  2.595596e-05
# actual :  -0.011570146
# difference :  2.4168752e-05
# actual :  -0.011545978
# difference :  1.9559637e-05
# actual :  -0.011526418
# difference :  1.7909333e-05
# actual :  -0.011508509
# difference :  1.439359e-05
# actual :  -0.011494115
# difference :  1.3139099e-05
# actual :  -0.011480976
# difference :  7.4999407e-06
# actual :  -0.011473476
# difference :  1.5934929e-06
# actual :  -0.011471882
# difference :  -6.64033e-07
# actual :  -0.0114725465
# difference :  -2.055429e-06
# actual :  -0.011474602
# difference :  -2.2305176e-06
# actual :  -0.011476832
# difference :  -1.296401e-06
# actual :  -0.011478129
# difference :  -1.4128163e-06
# actual :  -0.011479542
# difference :  8.867122e-06
# actual :  -0.011470675
# difference :  6.127171e-06
# actual :  -0.011464547
# difference :  2.8423965e-06
# actual :  -0.011461705
# difference :  -4.9360096e-08
# actual :  -0.011461754
# difference :  2.482906e-06
# actual :  -0.011459271
# difference :  2.2193417e-06
# actual :  -0.011457052
# difference :  1.5292317e-06
# actual :  -0.011455523
# difference :  1.3494864e-06
# actual :  -0.011454173
# difference :  8.409843e-07
# actual :  -0.011453332
# difference :  -2.621673e-06
# actual :  -0.011455954
# difference :  -4.307367e-06
# actual :  -0.011460261
# difference :  -5.3681433e-06
# actual :  -0.01146563
# difference :  -4.705973e-06
# actual :  -0.011470336
# difference :  5.2219257e-06
# actual :  -0.011465114
# difference :  4.385598e-06
# actual :  -0.011460728
# difference :  3.4626573e-06
# actual :  -0.011457265
# difference :  4.7562644e-06
# actual :  -0.011452509
# difference :  2.4288893e-06
# actual :  -0.01145008
# difference :  4.60539e-06
# actual :  -0.011445475
# difference :  1.3289042e-05
# actual :  -0.011432186
# difference :  1.1060387e-05
# actual :  -0.011421125
# difference :  2.9043294e-05
# actual :  -0.011392082
# difference :  3.1784177e-05
# actual :  -0.011360298
# difference :  2.1917745e-05
# actual :  -0.01133838
# difference :  1.9395724e-05
# actual :  -0.011318984
# difference :  1.7093495e-05
# actual :  -0.011301891
# difference :  2.0755455e-05
# actual :  -0.0112811355
# difference :  2.2943132e-05
# actual :  -0.011258192
# difference :  2.0627864e-05
# actual :  -0.0112375645
# difference :  1.8081628e-05
# actual :  -0.011219483
# difference :  1.0655262e-05
# actual :  -0.011208828
# difference :  8.137897e-06
# actual :  -0.01120069
# difference :  7.022172e-06
# actual :  -0.011193668
# difference :  6.9225207e-06
# actual :  -0.011186745
# difference :  9.488314e-06
# actual :  -0.011177257
# difference :  7.937662e-06
# actual :  -0.011169319
# difference :  1.6166829e-05
# actual :  -0.011153152
# difference :  1.4627352e-05
# actual :  -0.011138525
# difference :  1.4833175e-05
# actual :  -0.011123692
# difference :  9.11206e-06
# actual :  -0.01111458
# difference :  8.543953e-06
# actual :  -0.011106036
# difference :  1.8388964e-05
# actual :  -0.011087647
# difference :  1.680851e-05
# actual :  -0.011070838
# difference :  1.4888123e-05
# actual :  -0.01105595
# difference :  3.3183023e-06
# actual :  -0.011052632
# difference :  1.2191013e-06
# actual :  -0.011051413
# difference :  9.192154e-07
# actual :  -0.011050493
# difference :  -1.7993152e-06
# actual :  -0.011052293
# difference :  -1.7508864e-07
# actual :  -0.011052468
# difference :  -1.2184493e-05
# actual :  -0.011064652
# difference :  -1.2295321e-05
# actual :  -0.011076948
# difference :  -1.2094155e-05
# actual :  -0.011089042
# difference :  -1.283735e-05
# actual :  -0.011101879
# difference :  -1.27526e-05
# actual :  -0.011114632
# difference :  -8.768402e-06
# actual :  -0.0111234
# difference :  5.8971345e-06
# actual :  -0.011117503
# difference :  2.5732443e-06
# actual :  -0.01111493
# difference :  2.6207417e-06
# actual :  -0.011112309
# difference :  2.5229529e-06
# actual :  -0.011109786
# difference :  2.7380884e-06
# actual :  -0.011107048
# difference :  8.076429e-06
# actual :  -0.011098972
# difference :  1.0299496e-05
# actual :  -0.011088672
# difference :  9.336509e-06
# actual :  -0.011079336
# difference :  6.854534e-06
# actual :  -0.011072481
# difference :  6.010756e-06
# actual :  -0.01106647
# difference :  4.642643e-06
# actual :  -0.011061828
# difference :  7.972121e-07
# actual :  -0.01106103
# difference :  -1.6223639e-06
# actual :  -0.011062653
# difference :  -2.0042062e-06
# actual :  -0.011064657
# difference :  -3.470108e-06
# actual :  -0.011068127
# difference :  -5.713664e-06
# actual :  -0.011073841
# difference :  -6.383285e-06
# actual :  -0.011080224
# difference :  -5.87292e-06
# actual :  -0.011086097
# difference :  -5.4873526e-06
# actual :  -0.011091584
# difference :  -6.862916e-06
# actual :  -0.011098447
# difference :  -5.83753e-06
# actual :  -0.011104285
# difference :  -5.4500997e-06
# actual :  -0.011109735
# difference :  -4.9788505e-06
# actual :  -0.011114714
# difference :  -5.5916607e-06
# actual :  -0.011120305
# difference :  -5.1427633e-06
# actual :  -0.011125448
# difference :  -4.5550987e-06
# actual :  -0.011130003
# difference :  -1.937151e-07
# actual :  -0.011130197
# difference :  8.28132e-06
# actual :  -0.011121916
# difference :  7.4766576e-06
# actual :  -0.011114439
# difference :  7.905997e-06
# actual :  -0.011106533
# difference :  7.319264e-06
# actual :  -0.011099214
# difference :  6.700866e-06
# actual :  -0.011092513
# difference :  1.3986602e-05
# actual :  -0.011078526
# difference :  1.7348677e-05
# actual :  -0.011061178
# difference :  1.5923753e-05
# actual :  -0.011045254
# difference :  2.3457222e-05
# actual :  -0.011021797
# difference :  1.8237159e-05
# actual :  -0.011003559
# difference :  1.5363097e-05
# actual :  -0.010988196
# difference :  1.3246201e-05
# actual :  -0.01097495
# difference :  1.156237e-05
# actual :  -0.010963388
# difference :  8.52067e-06
# actual :  -0.010954867
# difference :  7.26711e-06
# actual :  -0.0109476
# difference :  6.293878e-06
# actual :  -0.010941306
# difference :  5.104579e-06
# actual :  -0.010936202
# difference :  4.0112063e-06
# actual :  -0.01093219
# difference :  2.6579946e-06
# actual :  -0.010929532
# difference :  2.1699816e-06
# actual :  -0.010927362
# difference :  2.4931505e-06
# actual :  -0.010924869
# difference :  1.2042001e-06
# actual :  -0.010923665
# difference :  5.500391e-06
# actual :  -0.010918165
# difference :  3.9311126e-06
# actual :  -0.0109142335
# difference :  2.6542693e-06
# actual :  -0.010911579
# difference :  -2.685003e-06
# actual :  -0.010914264
# difference :  -3.6675483e-06
# actual :  -0.010917932
# difference :  5.301088e-06
# actual :  -0.010912631
# difference :  9.667128e-07
# actual :  -0.010911664
# difference :  -9.685755e-08
# actual :  -0.010911761
# difference :  -1.8728897e-06
# actual :  -0.010913634
# difference :  -1.6503036e-06
# actual :  -0.010915284
# difference :  -2.3553148e-06
# actual :  -0.010917639
# difference :  -2.9588118e-06
# actual :  -0.010920598
# difference :  -2.8982759e-06
# actual :  -0.010923496
# difference :  -3.3639371e-06
# actual :  -0.01092686
# difference :  -2.861023e-06
# actual :  -0.010929721
# difference :  -3.222376e-06
# actual :  -0.010932944
# difference :  -3.0323863e-06
# actual :  -0.010935976
# difference :  1.1622906e-06
# actual :  -0.010934814
# difference :  1.5171245e-06
# actual :  -0.010933297
# difference :  1.6950071e-06
# actual :  -0.010931602
# difference :  9.835698e-06
# actual :  -0.010921766
# difference :  7.916242e-06
# actual :  -0.01091385
# difference :  1.0866672e-05
# actual :  -0.010902983
# difference :  8.320436e-06
# actual :  -0.010894663
# difference :  7.0137903e-06
# actual :  -0.010887649
# difference :  5.2247196e-06
# actual :  -0.010882424
# difference :  4.9350783e-06
# actual :  -0.010877489
# difference :  4.7013164e-06
# actual :  -0.010872788
# difference :  -5.4258853e-06
# actual :  -0.010878214
# difference :  -4.4163316e-06
# actual :  -0.01088263
# difference :  -5.7816505e-06
# actual :  -0.010888412
# difference :  -6.926246e-06
# actual :  -0.010895338
# difference :  -6.2147155e-06
# actual :  -0.010901553
# difference :  -1.8207356e-06
# actual :  -0.010903373
# difference :  -1.6521662e-06
# actual :  -0.0109050255
# difference :  -2.7203932e-06
# actual :  -0.010907746
# difference :  -3.3788383e-06
# actual :  -0.010911125
# difference :  5.026348e-06
# actual :  -0.010906098
# difference :  -1.0244548e-07
# actual :  -0.010906201
# difference :  -5.1893294e-06
# actual :  -0.01091139
# difference :  -4.769303e-06
# actual :  -0.0109161595
# difference :  -7.2196126e-06
# actual :  -0.010923379
# difference :  -5.2358955e-06
# actual :  -0.010928615
# difference :  -3.6163256e-06
# actual :  -0.010932231
# difference :  -3.6219135e-06
# actual :  -0.010935853
# difference :  -1.6121194e-06
# actual :  -0.010937465
# difference :  6.6878274e-06
# actual :  -0.0109307775
# difference :  5.1893294e-06
# actual :  -0.010925588
# difference :  1.2292527e-05
# actual :  -0.010913296
# difference :  1.0295771e-05
# actual :  -0.010903
# difference :  8.7386e-06
# actual :  -0.010894261
# difference :  7.498078e-06
# actual :  -0.010886763
# difference :  1.0094605e-05
# actual :  -0.010876669
# difference :  1.045689e-05
# actual :  -0.010866212
# difference :  1.4653429e-05
# actual :  -0.010851558
# difference :  1.36028975e-05
# actual :  -0.010837955
# difference :  1.2682751e-05
# actual :  -0.010825273
# difference :  1.2677163e-05
# actual :  -0.0108125955
# difference :  1.2164004e-05
# actual :  -0.0108004315
# difference :  1.0174699e-05
# actual :  -0.010790257
# difference :  5.312264e-06
# actual :  -0.0107849445
# difference :  5.044043e-06
# actual :  -0.0107799005
# difference :  1.2211502e-05
# actual :  -0.010767689
# difference :  8.855946e-06
# actual :  -0.010758833
# difference :  8.769333e-06
# actual :  -0.010750064
# difference :  6.6282228e-06
# actual :  -0.0107434355
# difference :  4.275702e-06
# actual :  -0.01073916
# difference :  2.4726614e-06
# actual :  -0.010736687
# difference :  1.1660159e-06
# actual :  -0.010735521
# difference :  -1.9837171e-07
# actual :  -0.010735719
# difference :  -7.869676e-07
# actual :  -0.010736506
# difference :  -1.383014e-06
# actual :  -0.010737889
# difference :  6.2752515e-06
# actual :  -0.010731614
# difference :  1.2909062e-05
# actual :  -0.010718705
# difference :  1.2666918e-05
# actual :  -0.010706038
# difference :  1.3113953e-05
# actual :  -0.010692924
# difference :  1.1681579e-05
# actual :  -0.010681243
# difference :  8.361414e-06
# actual :  -0.010672881
# difference :  7.4161217e-06
# actual :  -0.010665465
# difference :  8.739531e-06
# actual :  -0.010656726
# difference :  1.18445605e-05
# actual :  -0.010644881
# difference :  1.0243617e-05
# actual :  -0.010634637
# difference :  6.660819e-06
# actual :  -0.010627977
# difference :  5.2992254e-06
# actual :  -0.010622677
# difference :  3.04915e-06
# actual :  -0.010619628
# difference :  5.136244e-06
# actual :  -0.010614492
# difference :  3.9916486e-06
# actual :  -0.0106105
# difference :  3.8649887e-07
# actual :  -0.010610114
# difference :  2.6077032e-07
# actual :  -0.010609853
# difference :  -2.370216e-06
# actual :  -0.010612223
# difference :  -1.8328428e-06
# actual :  -0.010614056
# difference :  4.051253e-06
# actual :  -0.010610005
# difference :  1.0617077e-05
# actual :  -0.010599388
# difference :  1.6554259e-05
# actual :  -0.010582834
# difference :  1.47577375e-05
# actual :  -0.010568076
# difference :  1.3278797e-05
# actual :  -0.010554797
# difference :  1.1704862e-05
# actual :  -0.010543092
# difference :  1.4072284e-05
# actual :  -0.01052902
# difference :  1.3730489e-05
# actual :  -0.010515289
# difference :  1.8708408e-05
# actual :  -0.010496581
# difference :  1.4286488e-05
# actual :  -0.0104822945
# difference :  1.1713244e-05
# actual :  -0.010470581
# difference :  1.0184944e-05
# actual :  -0.010460396
# difference :  1.0740943e-05
# actual :  -0.010449655
# difference :  1.0770746e-05
# actual :  -0.010438885
# difference :  5.929731e-06
# actual :  -0.010432955
# difference :  5.046837e-06
# actual :  -0.010427908
# difference :  4.6845526e-06
# actual :  -0.0104232235
# difference :  1.1362135e-06
# actual :  -0.010422087
# difference :  3.0826777e-07
# actual :  -0.010421779
# difference :  -1.0598451e-06
# actual :  -0.010422839
# difference :  4.916452e-06
# actual :  -0.010417922
# difference :  2.5788322e-06
# actual :  -0.010415344
# difference :  2.341345e-06
# actual :  -0.010413002
# difference :  1.5664846e-06
# actual :  -0.010411436
# difference :  -1.3969839e-07
# actual :  -0.010411575
# difference :  8.1025064e-08
# actual :  -0.010411494
# difference :  -8.000061e-07
# actual :  -0.010412294
# difference :  -1.8626451e-06
# actual :  -0.010414157
# difference :  -1.6000122e-06
# actual :  -0.010415757
# difference :  4.697591e-06
# actual :  -0.0104110595
# difference :  3.7001446e-06
# actual :  -0.010407359
# difference :  5.759299e-06
# actual :  -0.0104016
# difference :  6.4363703e-06
# actual :  -0.010395164
# difference :  2.4931505e-06
# actual :  -0.0103926705
# difference :  1.9408762e-06
# actual :  -0.01039073
# difference :  2.2388995e-06
# actual :  -0.010388491
# difference :  2.8014183e-06
# actual :  -0.010385689
# difference :  9.268522e-06
# actual :  -0.010376421
# difference :  7.854775e-06
# actual :  -0.010368566
# difference :  6.7111105e-06
# actual :  -0.010361855
# difference :  1.4564022e-05
# actual :  -0.010347291
# difference :  1.2234785e-05
# actual :  -0.010335056
# difference :  1.656916e-05
# actual :  -0.010318487
# difference :  1.6734004e-05
# actual :  -0.010301753
# difference :  1.7756596e-05
# actual :  -0.010283996
# difference :  1.8162653e-05
# actual :  -0.010265834
# difference :  1.4726073e-05
# actual :  -0.010251108
# difference :  1.2492761e-05
# actual :  -0.010238615
# difference :  1.1085533e-05
# actual :  -0.010227529
# difference :  4.3874606e-06
# actual :  -0.010223142
# difference :  3.3341348e-07
# actual :  -0.010222808
# difference :  -4.260801e-06
# actual :  -0.010227069
# difference :  2.9634684e-06
# actual :  -0.010224106
# difference :  -5.8766454e-07
# actual :  -0.010224693
# difference :  -4.7162175e-06
# actual :  -0.01022941
# difference :  -2.5099143e-06
# actual :  -0.01023192
# difference :  -3.7467107e-06
# actual :  -0.010235666
# difference :  -4.1676685e-06
# actual :  -0.010239834
# difference :  -3.7802383e-06
# actual :  -0.010243614
# difference :  9.55537e-07
# actual :  -0.010242659
# difference :  -9.108335e-07
# actual :  -0.0102435695
# difference :  -2.2342429e-06
# actual :  -0.010245804
# difference :  -1.5236437e-06
# actual :  -0.010247327

# %%
import torch
import torch.nn as nn
import torch.optim as optim

hidden_layers = [4, 8, 16, 32]

criterion = nn.CrossEntropyLoss()
results = []

for hidden_layer in hidden_layers:

    print(f"\nTraining with hidden_layer = {hidden_layer}")

    model = Model(embd_dim, hidden_layer).to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    model.train()

    for epoch in range(10000):   # reduce for faster experimentation
        idx = torch.randint(0, len(x_train), (batch_size,), device=device)
        rand_x = x_train[idx]
        rand_y = y_train[idx]

        optimizer.zero_grad(set_to_none=True)
        outputs = model(rand_x)
        loss = criterion(outputs, rand_y)
        loss.backward()
        optimizer.step()

    model.eval()

    with torch.no_grad():
        train_loss = criterion(model(x_train), y_train).item()
        val_loss   = criterion(model(x_val), y_val).item()
        test_loss  = criterion(model(x_test), y_test).item()

    print(f"Hidden: {hidden_layer} | Train: {train_loss:.4f} | Val: {val_loss:.4f} | Test: {test_loss:.4f}")

    results.append({
        "hidden": hidden_layer,
        "train_loss": train_loss,
        "val_loss": val_loss,
        "test_loss": test_loss
    })

# %%
first = model.embedding.weight[:, 0].detach().float().cpu().numpy()
second = model.embedding.weight[:, 1].detach().float().cpu().numpy()
for i in range(len(first)):
    word = itos[i]
    # if word in ['h','e','a','r', ' ', 'm', 'e','p','3']:
    plt.scatter(first[i], second[i], s=500)
    plt.text(first[i], second[i], word, fontsize=10, ha='center', va='center')

# %%
plt.plot(lr_iterations, lr_losses)
plt.show()

# %%
# print(vocab_size)
torch.set_printoptions(sci_mode=False,precision=4)
print(model.embedding.weight.float())
print(model.linear_2.weight.cpu().detach())
for name, param in model.named_parameters():
    print(f"{name}: {param.numel()}")

# %%
#Test
model.eval()
logging = True
final_text = 'You are all resolved rather to die than'.lower()
for _ in range(200):
    x = torch.tensor(encoder(final_text[-context_size:]))
    x = torch.unsqueeze(x,0)
    output = model(x)
    final = torch.max(output, 1)
    # print(final)
    y = decoder([final[1].item()])
    final_text+=y[0]
print(final_text)

# %%
import torch
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Get embeddings (assuming vocab_size >= 20)
embeddings = model.embedding.weight.detach().numpy()

# Reduce 10D → 2D
pca = PCA(n_components=2)
reduced = pca.fit_transform(embeddings)

# Plot all 20 points in ONE scatter
plt.figure(figsize=(8, 8))

# Label each point (0–19)
for i in range(embeddings.shape[0]):
    word = itos[i]
    if word in ['h','e','a','r', ' ', 'm', 'e','s', '3']:
        plt.scatter(reduced[i, 0], reduced[i, 1], s=100)
        plt.text(reduced[i, 0], reduced[i, 1], word, ha='center', va='center')

plt.title("20 Embeddings Visualization (PCA)")
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.show()

# %%
a = torch.tensor([ 1.2496,  4.0898, -0.5284,  1.0659, -2.6788,  0.3610, -1.3946,  2.2194,
         -1.9383, -0.1370,  0.0481,  2.6672, -0.5284,  1.0659, -1.9383, -0.1370])

b = torch.tensor([  3.8696,   0.7342,   3.6664,  -0.3347,  -0.6673,  -2.9894,  -1.8589,
           1.7606,   2.5973,  -6.5067,   0.9466,   0.7771,   1.5486,  -1.4092,
           0.7132,  -3.9513])

a = torch.unsqueeze(a, 0)
b = torch.unsqueeze(b, 1)

print(a.shape)
print(b.shape)
print(a @ b)
